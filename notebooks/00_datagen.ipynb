# %%
from pathlib import Path
import sys
from datetime import date

cwd = Path.cwd().parent.joinpath("money_map")
sys.path.append(cwd)
from money_map.data.rbpn_generators import RBPN_Generator

generator = RBPN_Generator()
start_date = date(2024,1,1)
end_date = date(2024,12,1)
start_balance = 30000
fake_data = generator.create_random_transactions(start_date=start_date,
                                                 end_date=end_date,
                                                 num_unique_sender=1,
                                                 num_unique_receiver=10,
                                                 start_balance=start_balance
                                                 )

fake_data
# Out:
#   Bezeichnung Auftragskonto      IBAN Auftragskonto   BIC Auftragskonto  \
# 1                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 5                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 2                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 9                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 3                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 0                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 8                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 7                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 6                 Girokonto  GB87YODA19011530005979  OECF10873187191890
# 4                 Girokonto  GB87YODA19011530005979  OECF10873187191890
#
#   Bankname Auftragskonto   Name Zahlungsbeteiligter IBAN Zahlungsbeteiligter  \
# 1                   RBPN            Bennett-Montoya   GB67IUGL12942571163040
# 5                   RBPN              Michelle Rice   GB43ZPPD88243156485683
# 2                   RBPN              Michael Brown   GB76GBNM53648465928144
# 9                   RBPN             Jessica Graham   GB51CSXN95890678261885
# 3                   RBPN               Paul Roberts   GB51JSGQ41893585574189
# 0                   RBPN              Justin Newman   GB14UGOQ08105276201972
# 8                   RBPN               Andrew Myers   GB25CZXL23186024805804
# 7                   RBPN               Joseph Frost   GB16TEIY67452173731428
# 6                   RBPN  Wright, Randall and Hodge   GB28TOTO68584664975342
# 4                   RBPN               Erickson PLC   GB86SRTT70515609915393
#
#   BIC (SWIFT-Code) Zahlungsbeteiligter  \
# 1                   HQCZ54719416316378
# 5                   TPVV75781871132952
# 2                   NMSI81643496057372
# 9                   USQR38161582159741
# 3                   SRDH45206003258568
# 0                   CRGE05182470640242
# 8                   XQAB67042397904377
# 7                   IEMG38823596085338
# 6                   FNFB39858367086111
# 4                   LQWY69700714652730
#
#                                     Verwendungszweck Buchungstag Valutadatum  \
# 1  Line catch answer close certain national resea...  2024-02-29  2024-02-29
# 5    Upon resource total coach win across others TV.  2024-05-12  2024-05-12
# 2                     Trouble thousand time forward.  2024-05-22  2024-05-22
# 9                               Tv among maybe pull.  2024-06-22  2024-06-22
# 3  Performance attention most stuff read trial se...  2024-07-12  2024-07-12
# 0                Safe mind just every sing indicate.  2024-08-19  2024-08-19
# 8                       Tree red present pick paper.  2024-09-01  2024-09-01
# 7                              Type laugh task each.  2024-09-28  2024-09-28
# 6                     Space ago such Congress chair.  2024-11-08  2024-11-08
# 4            Main out loss lose knowledge room save.  2024-11-11  2024-11-11
#
#     Betrag                 Buchungstext Waehrung Bemerkung Kategorie  \
# 1  -305.53  Aufladung Mobilfunkguthaben      EUR      None      None
# 5  -121.46          Kartenzahlung V PAY      EUR      None      None
# 2  -185.44  Aufladung Mobilfunkguthaben      EUR      None      None
# 9  -211.96       Kartenzahlung girocard      EUR      None      None
# 3  2799.81                  LOHN/GEHALT      EUR      None      None
# 0  -271.52                    ABSCHLUSS      EUR      None      None
# 8  -223.83          Kartenzahlung V PAY      EUR      None      None
# 7  -171.05                 DAUERAUFTRAG      EUR      None      None
# 6  -102.85  Aufladung Mobilfunkguthaben      EUR      None      None
# 4  -208.51          Auszahlung girocard      EUR      None      None
#
#   Steuerrelevant Glaeubiger ID Mandatsreferenz  Saldo nach Buchung
# 1           None          None            None            29694.47
# 5           None          None            None            29573.01
# 2           None          None            None            29387.57
# 9           None          None            None            29175.61
# 3           None          None            None            31975.42
# 0           None          None            None            31703.90
# 8           None          None            None            31480.07
# 7           None          None            None            31309.02
# 6           None          None            None            31206.17
# 4           None          None            None            30997.66

# %%
    # transaction_id: Mapped[str] = mapped_column(String(40),nullable=False,primary_key=True)
    # sender_account_type: Mapped[str] = mapped_column(String(40),nullable=False)
    # sender_iban: Mapped[str] = mapped_column(String(40),nullable=False)
    # sender_bic: Mapped[str] = mapped_column(String(40),nullable=True)
    # sender_bank_name: Mapped[str] = mapped_column(String(80),nullable=False)
    # receiver_name: Mapped[str] = mapped_column(String(80),nullable=False)
    # receiver_iban: Mapped[str] = mapped_column(String(40),nullable=False)
    # receiver_bic: Mapped[str] = mapped_column(String(40),nullable=True)
    # booking_date: Mapped[datetime.date] = mapped_column(Date(),nullable=False)
    # value_date: Mapped[datetime.date] = mapped_column(Date(),nullable=False)
    # amount: Mapped[float] = mapped_column(Float(),nullable=False)
    # currency: Mapped[str] = mapped_column(String(20),nullable=False)
    # booking_text: Mapped[str] = mapped_column(String(40),nullable=False)
    # purpose: Mapped[str] = mapped_column(String(140),nullable=False)
    # balance_after_booking: Mapped[float] = mapped_column(Float(),nullable=False)
    # notes: Mapped[str] = mapped_column(String(40),nullable=True)
    # default_category: Mapped[str] = mapped_column(String(80),nullable=True)
    # tax_relevant: Mapped[str] = mapped_column(String(40),nullable=True)
    # creditor_id: Mapped[str] = mapped_column(String(40),nullable=True)
    # mandate_reference: Mapped[str] = mapped_column(String(40),nullable=True)
    # purpose_char: Mapped[str] = mapped_column(String(140),nullable=False)
